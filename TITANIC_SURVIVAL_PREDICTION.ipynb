# %% [markdown]
# <a href="https://colab.research.google.com/github/Bijo-Varghese-MT/CognoRise-InfoTech/blob/main/TITANIC_SURVIVAL_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**TITANIC SURVIVAL PREDICTION**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# survival - Survival (0 = No; 1 = Yes)
#
# class - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
#
# name - Name
#
# sex - Sex
#
# age - Age
#
# sibsp - Number of Siblings/Spouses Aboard
#
# parch - Number of Parents/Children Aboard
#
# ticket - Ticket Number
#
# fare - Passenger Fare
#
# cabin - Cabin
#
# embarked - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/titatic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.shape
# Out:
# (418, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop(['PassengerId','Name','Ticket'],axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0           0       3    male  34.5      0      0    7.8292   NaN        Q
# 1           1       3  female  47.0      1      0    7.0000   NaN        S
# 2           0       2    male  62.0      0      0    9.6875   NaN        Q
# 3           0       3    male  27.0      0      0    8.6625   NaN        S
# 4           1       3  female  22.0      1      1   12.2875   NaN        S
# ..        ...     ...     ...   ...    ...    ...       ...   ...      ...
# 413         0       3    male   NaN      0      0    8.0500   NaN        S
# 414         1       1  female  39.0      0      0  108.9000  C105        C
# 415         0       3    male  38.5      0      0    7.2500   NaN        S
# 416         0       3    male   NaN      0      0    8.0500   NaN        S
# 417         0       3    male   NaN      1      1   22.3583   NaN        C
#
# [418 rows x 9 columns]

# %% [markdown]
# we have droped 'Cabin' variable because of too many missing values.

# %%
df.drop(['Cabin'],axis=1,inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male   NaN      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male   NaN      0      0    8.0500        S
# 417         0       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
df=df.drop_duplicates()
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 411         1       1  female  37.0      1      0   90.0000        Q
# 412         1       3  female  28.0      0      0    7.7750        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 417         0       3    male   NaN      1      1   22.3583        C
#
# [380 rows x 8 columns]

# %% [markdown]
# We have imputed missing values with mean for 'Age' and median for 'Fare' variables

# %%
sns.histplot(x=df['Age'],kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x=df['Fare'],kde=True)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
 a=df['Age'].mean()
 b=df['Fare'].median()

# %%
df['Age'].fillna(a,inplace=True)
df['Fare'].fillna(b,inplace=True)
# Out:
# <ipython-input-18-17e0628b9ca4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(a,inplace=True)
# <ipython-input-18-17e0628b9ca4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Fare'].fillna(b,inplace=True)

# %%
df.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# DATA VISUALIZATION

# %%
labels=['not survived','survived']
plt.figure(figsize=(6,6))
x=df['Survived'].value_counts()
explode = (0.1,0)
plt.pie(x, labels=labels, autopct='%1.1f%%', startangle=140, explode=explode)
plt.title("Survived Status")
plt.axis('equal')
plt.show()

# %%
for column in ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']:
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    ax = sns.countplot(x=column, data=df)
    ax.bar_label(ax.containers[0])

    plt.subplot(1,2,2)
    ax = sns.countplot(x=column, data=df, hue='Survived')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    plt.show()

# %%
#HEATMAP

plt.figure(figsize=(10,5))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-22-bdb593b14647>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
#To check outlayers
for i in['Survived','Pclass','Age','SibSp','Parch','Fare']:
  sns.boxplot(x=i,data=df)
  plt.show()

# %%
#To remove outlayers
for i in['SibSp','Parch','Fare']:
  Q1=df[i].quantile(0.25)
  Q2=df[i].quantile(0.75)
  IQR=Q2-Q1
  lower=Q1-3*IQR
  upper=Q2+3*IQR
  df=df[(df[i]>=lower)&(df[i]<=upper)]
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  34.500000      0      0   7.8292        Q
# 1           1       3  female  47.000000      1      0   7.0000        S
# 2           0       2    male  62.000000      0      0   9.6875        Q
# 3           0       3    male  27.000000      0      0   8.6625        S
# 5           0       3    male  14.000000      0      0   9.2250        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 405         0       2    male  20.000000      0      0  13.8625        C
# 406         0       2    male  23.000000      1      0  10.5000        S
# 408         1       3  female  30.324534      0      0   7.7208        Q
# 412         1       3  female  28.000000      0      0   7.7750        S
# 415         0       3    male  38.500000      0      0   7.2500        S
#
# [266 rows x 8 columns]

# %%
#ENCODING


from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()
df["Sex"]=label.fit_transform(df["Sex"])
df['Embarked']=label.fit_transform(df['Embarked'])
df
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1  34.500000      0      0   7.8292         1
# 1           1       3    0  47.000000      1      0   7.0000         2
# 2           0       2    1  62.000000      0      0   9.6875         1
# 3           0       3    1  27.000000      0      0   8.6625         2
# 5           0       3    1  14.000000      0      0   9.2250         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 405         0       2    1  20.000000      0      0  13.8625         0
# 406         0       2    1  23.000000      1      0  10.5000         2
# 408         1       3    0  30.324534      0      0   7.7208         1
# 412         1       3    0  28.000000      0      0   7.7750         2
# 415         0       3    1  38.500000      0      0   7.2500         2
#
# [266 rows x 8 columns]

# %% [markdown]
# Spliting Independent and Dependent Features

# %%
x=df.drop('Survived',axis=1)
x
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 0         3    1  34.500000      0      0   7.8292         1
# 1         3    0  47.000000      1      0   7.0000         2
# 2         2    1  62.000000      0      0   9.6875         1
# 3         3    1  27.000000      0      0   8.6625         2
# 5         3    1  14.000000      0      0   9.2250         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 405       2    1  20.000000      0      0  13.8625         0
# 406       2    1  23.000000      1      0  10.5000         2
# 408       3    0  30.324534      0      0   7.7208         1
# 412       3    0  28.000000      0      0   7.7750         2
# 415       3    1  38.500000      0      0   7.2500         2
#
# [266 rows x 7 columns]

# %%
y=df['Survived']
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 5      0
#       ..
# 405    0
# 406    0
# 408    1
# 412    1
# 415    0
# Name: Survived, Length: 266, dtype: int64

# %% [markdown]
# #MODEL SELECTION

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_train
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 251       3    1  20.000000      0      0   7.9250         2
# 134       3    1  43.000000      0      0   7.8958         2
# 357       3    1  30.324534      0      0   7.8792         2
# 208       1    0  33.000000      0      0  27.7208         0
# 128       2    1  42.000000      0      0  13.0000         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 25        3    1  50.000000      1      0  14.5000         2
# 276       2    1  28.000000      0      0  10.5000         2
# 96        1    0  76.000000      1      0  78.8500         2
# 143       2    1  28.000000      0      0  26.0000         2
# 135       3    1  24.000000      0      0   7.8542         2
#
# [186 rows x 7 columns]

# %%
x_test
# Out:
#      Pclass  Sex        Age  SibSp  Parch     Fare  Embarked
# 264       2    1  30.000000      0      0  12.7375         0
# 166       1    1  48.000000      0      0  50.4958         0
# 200       3    0  30.324534      0      0  15.5000         1
# 325       3    1  23.000000      0      0   7.0500         2
# 58        3    1  30.324534      1      0  16.1000         2
# ..      ...  ...        ...    ...    ...      ...       ...
# 112       1    0  36.000000      0      0  31.6792         0
# 266       1    1  30.324534      0      0   0.0000         2
# 157       3    0  23.000000      0      0   7.8542         2
# 152       3    1  60.500000      0      0  15.2458         2
# 105       3    1  28.000000      0      0  22.5250         2
#
# [80 rows x 7 columns]

# %%
y_train
# Out:
# 251    0
# 134    0
# 357    0
# 208    1
# 128    0
#       ..
# 25     0
# 276    0
# 96     1
# 143    0
# 135    0
# Name: Survived, Length: 186, dtype: int64

# %%
y_test
# Out:
# 264    0
# 166    0
# 200    1
# 325    0
# 58     0
#       ..
# 112    1
# 266    0
# 157    1
# 152    0
# 105    0
# Name: Survived, Length: 80, dtype: int64

# %%
# Applying standard Scaler for scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.83324076,  0.63126559, -1.00685034, ...,  0.        ,
#         -0.61962468,  0.64959092],
#        [ 0.83324076,  0.63126559,  1.00350392, ...,  0.        ,
#         -0.62119798,  0.64959092],
#        [ 0.83324076,  0.63126559, -0.10441681, ...,  0.        ,
#         -0.62209239,  0.64959092],
#        ...,
#        [-1.64648373, -1.5841193 ,  3.88792525, ...,  0.        ,
#          3.20181319,  0.64959092],
#        [-0.40662149,  0.63126559, -0.30759668, ...,  0.        ,
#          0.35425603,  0.64959092],
#        [ 0.83324076,  0.63126559, -0.65722351, ...,  0.        ,
#         -0.62343939,  0.64959092]])

# %%
x_test
# Out:
# array([[-0.40662149,  0.63126559, -0.13278327, -0.51072625,  0.        ,
#         -0.36032726, -1.81620319],
#        [-1.64648373,  0.63126559,  1.44053745, -0.51072625,  0.        ,
#          1.67408935, -1.81620319],
#        [ 0.83324076, -1.5841193 , -0.10441681, -0.51072625,  0.        ,
#         -0.2114838 , -0.58330613],
#        [ 0.83324076,  0.63126559, -0.74463022, -0.51072625,  0.        ,
#         -0.66676967,  0.64959092],
#        [ 0.83324076,  0.63126559, -0.10441681,  1.2816338 ,  0.        ,
#         -0.17915581,  0.64959092],
#        [ 0.83324076,  0.63126559, -0.83203692, -0.51072625,  0.        ,
#         -0.62770668,  0.64959092],
#        [ 0.83324076,  0.63126559,  0.04203015, -0.51072625,  0.        ,
#          0.16702308,  0.64959092],
#        [ 0.83324076, -1.5841193 , -0.10441681, -0.51072625,  0.        ,
#         -0.62995348, -0.58330613],
#        [ 0.83324076,  0.63126559, -0.65722351, -0.51072625,  0.        ,
# ...

# %%
#model
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
dt = DecisionTreeClassifier()
model_lst=[rf,dt]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, ConfusionMatrixDisplay

for i in model_lst:
    print(i)
    i.fit(x_train, y_train)
    print('-' * 100)
    y_pred = i.predict(x_test)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("Confusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Display confusion matrix using ConfusionMatrixDisplay
    labels = ['0', '1']
    cm = confusion_matrix(y_test, y_pred)
    cmd = ConfusionMatrixDisplay(cm, display_labels=labels)
    cmd.plot()
# Out:
# RandomForestClassifier()
# ----------------------------------------------------------------------------------------------------
# Accuracy: 1.0
# Confusion Matrix:
# [[56  0]
#  [ 0 24]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80
#
# DecisionTreeClassifier()
# ----------------------------------------------------------------------------------------------------
# Accuracy: 1.0
# Confusion Matrix:
# [[56  0]
#  [ 0 24]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        56
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        80
# ...

# %%
from sklearn.tree import plot_tree
plot_tree(i, filled=True, feature_names=list(df.columns))
plt.show()
